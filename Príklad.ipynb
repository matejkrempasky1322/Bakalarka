# %% [markdown]
# # Hlavný nadpis
# ## Podnadpis
# ### Sekcia
#
# **tučné písmo**
# *kurzíva*
# `kód v riadku`
#
# - položka
# - položka
# - položka
#
# 1. prvá
# 2. druhá
# 3. tretia
#
# Rýchlosť: $v(t) = v_0 + a \cdot t$
#
# $$s(t) = s_0 + v_0 t + \frac{1}{2} a t^2$$
#
# | Veličina   | Symbol | Jednotka |
# |------------|--------|----------|
# | Rýchlosť   | v      | m/s      |
# | Zrýchlenie | a      | m/s²     |
# | Poloha     | s      | m        |
